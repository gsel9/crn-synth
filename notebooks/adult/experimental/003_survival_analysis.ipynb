# %% [markdown]
# # Generate synthetic data
# Generating synthetic data using public libraries for the 'adult' dataset.

# %% [markdown]
# ## Load libraries and define settings

# %%
# general dependencies
import numpy as np
import pandas as pd
import sys
import os
from pathlib import Path
from lifelines import KaplanMeierFitter
from lifelines.datasets import load_waltons, load_gbsg2


# synthesis methods
from synthcity.plugins import Plugins
from synthcity.plugins.core.dataloader import GenericDataLoader
from synthcity.benchmark import Benchmarks

from synthesis.synthesizers.privbayes import PrivBayes
from synthesis.evaluation.metrics import MarginalComparison, AssociationsComparison

# repo code
from crnsynth.configs import config
from crnsynth.synth.custom_generators.privbayes_dk import PrivBayesDK
from crnsynth.synth.custom_generators.marginal_dk import MarginalDK
from crnsynth.synth.custom_generators.uniform_dk import UniformDK

from crnsynth.process import util
from crnsynth.evaluation import visual
from crnsynth.synth.synthpipe import BaseSynthPipe

# gives extra pandas methods for dataframes: bin_numeric_column, sample_from_binned_column
from synthesis.transformers import deidentification, generalization

# %%
# autoreload changes from local files
# %load_ext autoreload
# %autoreload 2

# pandas show full output
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 200)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# privacy budget for differentially private algorithms
EPSILON = 1

# dataset
DATASET_NAME = 'adult'

# %% [markdown]
# ## Load and process dataset

# %%
df_adult = pd.read_csv(config.PATH_DATA[DATASET_NAME])
df_adult.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
df_survival = load_gbsg2()
df_survival.head()
# Out:
#   horTh  age menostat  tsize tgrade  pnodes  progrec  estrec  time  cens
# 0    no   70     Post     21     II       3       48      66  1814     1
# 1   yes   56     Post     12     II       7       61      77  2018     1
# 2   yes   58     Post     35     II       9       52     271   712     1
# 3   yes   59     Post     17     II       4       60      29  1807     1
# 4    no   73     Post     35     II       1       26      65   772     1

# %%
kmf = KaplanMeierFitter(label="Survival example")
kmf.fit(df_survival['time'], df_survival['cens'])
kmf.plot()
# Out:
# The `plot` function is deprecated, and will be removed in future versions. Use `plot_survival_function`
# <Axes: xlabel='timeline'>

# %%
df_survival.describe()
# Out:
#               age       tsize      pnodes      progrec       estrec  \
# count  686.000000  686.000000  686.000000   686.000000   686.000000
# mean    53.052478   29.329446    5.010204   109.995627    96.252187
# std     10.120739   14.296217    5.475483   202.331552   153.083963
# min     21.000000    3.000000    1.000000     0.000000     0.000000
# 25%     46.000000   20.000000    1.000000     7.000000     8.000000
# 50%     53.000000   25.000000    3.000000    32.500000    36.000000
# 75%     61.000000   35.000000    7.000000   131.750000   114.000000
# max     80.000000  120.000000   51.000000  2380.000000  1144.000000
#
#               time        cens
# count   686.000000  686.000000
# mean   1124.489796    0.435860
# std     642.791948    0.496231
# min       8.000000    0.000000
# 25%     567.750000    0.000000
# 50%    1084.000000    0.000000
# 75%    1684.750000    1.000000
# max    2659.000000    1.000000

# %%
from synthcity.plugins import Plugins
from synthcity.plugins.core.dataloader import SurvivalAnalysisDataLoader

# get survival plugin
survival_plugin = Plugins().get('survival_ctgan')

loader_survival = SurvivalAnalysisDataLoader(df_survival, time_to_event_column='time', target_column='cens')
survival_plugin.fit(loader_survival)
# Out:
# [2024-01-12T12:47:40.077865+0100][15113][CRITICAL] module disabled: /Users/dknoors/miniconda3/envs/crnsynth/lib/python3.9/site-packages/synthcity/plugins/generic/plugin_goggle.py
# [2024-01-12T12:47:40.090864+0100][15113][CRITICAL] module disabled: /Users/dknoors/miniconda3/envs/crnsynth/lib/python3.9/site-packages/synthcity/plugins/generic/plugin_goggle.py
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
# Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
# `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
# Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
# `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
# Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
# Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
# Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
# `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
# Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#  40%|███▉      | 799/2000 [01:10<01:46, 11.32it/s]

# %%
df_synth_survival = survival_plugin.generate(1000).dataframe()
df_synth_survival.head()
# Out:
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   horTh  age menostat  tsize tgrade  pnodes  progrec  estrec  time  cens
# 0    no   46      Pre      7     II       1       66       1  1349     0
# 1    no   61     Post     16     II       1        7      15   372     0
# 2    no   44      Pre     16    III       1        4      79   284     0
# 3   yes   45     Post     12      I       1       94      85  1208     0
# 4    no   47      Pre     19     II       6       10       4   811     0

# %%
kmf = KaplanMeierFitter(label="Survival example")
kmf.fit(df_synth_survival['time'], df_synth_survival['cens'])
kmf.plot()
# Out:
# The `plot` function is deprecated, and will be removed in future versions. Use `plot_survival_function`
# <Axes: xlabel='timeline'>

# %% [markdown]
# ## Generalized

# %%
class SurvivalSynthPipe(BaseSynthPipe):
    def __init__(
        self,
        generator,
        data_name="survival",
        target_column="cens",
        time_to_event_column="time",
        test_size=0.2,
        output_train_format=False,
        generalize=True,
        data_loader_name="survival",
        random_state=None,
        warn=True,
        verbose=2,
    ) -> None:
        super().__init__(
            generator=generator,
            data_name=data_name,
            target_column=target_column,
            test_size=test_size,
            output_train_format=output_train_format,
            generalize=generalize,
            data_loader_name=data_loader_name,
            random_state=random_state,
            warn=warn,
            verbose=verbose,
        )
        self.time_to_event_column = time_to_event_column



    def fit(self, data_real, data_loader_kwargs=None):
        """Fit generator on processed real data"""
        # only generalize training data to ensure that test data remains in same format as original

        # define loader
        data_loader_kwargs = data_loader_kwargs or {}
        loader = self._data_loader_fn(data_real, data_loader_kwargs)

        if self.generalize:
            data_real = self._generalize_data(loader.dataframe())

        self._check_input_data(data_real)

        # assign back to loader
        loader.data = data_real


        self.generator.fit(loader)

    def _generalize_data(self, data_real):
        data_real = data_real.bin_numeric_column(
            column_name="age", n_bins=5, col_min=21, col_max=80, strategy="quantile"
        ).bin_numeric_column(
            column_name="time",
            n_bins=5,
            col_min=1,
            col_max=2700,
            strategy="quantile",
        )
        return super()._generalize_data(data_real)

    def _reverse_generalization(self, data_synth):
        data_synth = data_synth.sample_from_binned_column(
            column_name="age",
            numeric_type="int",
            mean=53,
            std=10,
            random_state=self.random_state,
        ).sample_from_binned_column(
            column_name="time",
            numeric_type="int",
            mean=1100,
            std=600,
            random_state=self.random_state,
        )
        return super()._reverse_generalization(data_synth)


survival_synth_pipe = SurvivalSynthPipe(generator=survival_plugin)
df_train, df_test = survival_synth_pipe.process_data(df_survival)

df_train.head()
# Out:
#     horTh  age menostat  tsize tgrade  pnodes  progrec  estrec  time  cens
# 335   yes   44      Pre     28    III      17        2       3   227     1
# 145   yes   64     Post     30    III      12        0       0   392     1
# 123    no   39      Pre     30    III       1        0       0  1434     0
# 127    no   58     Post     50     II       7       77      77   547     1
# 434    no   50      Pre     18    III       1        1       4    17     0

# %%
T = df_train['time']
data_filtered = df_train[T > 0]

# %%
df_train.shape
# Out:
# (548, 10)

# %%
data_filtered.shape
# Out:
# (548, 10)

# %%
data_loader_kwargs = {
    "time_to_event_column": "time",
    "target_column": "cens",
}
survival_synth_pipe.fit(df_train, data_loader_kwargs=data_loader_kwargs)
# Out:
# Using data loader for survival
# WARNING: Rare categories in column 'tsize' that occur less than 5.0% of the records: [40, 22, 21, 15, 23, 27, 24, 18, 12, 28, 50, 45, 17, 16, 55, 60, 19, 32, 70, 10, 13, 26, 36, 38, 42, 31, 33, 29, 34, 100, 14, 8, 37, 44, 58, 65, 39, 7, 52, 80, 57, 48, 49, 9, 78, 11, 75, 120, 56, 4, 61, 43]
# WARNING: Rare categories in column 'pnodes' that occur less than 5.0% of the records: [6, 9, 8, 10, 11, 12, 13, 16, 19, 18, 20, 17, 15, 14, 24, 35, 21, 51, 33, 30, 36, 38, 23, 26]
# WARNING: Rare categories in column 'progrec' that occur less than 5.0% of the records: [1, 2, 6, 8, 26, 5, 7, 10, 3, 9, 20, 13, 16, 28, 11, 4, 23, 24, 48, 18, 25, 22, 27, 21, 64, 32, 12, 14, 82, 74, 33, 56, 100, 40, 170, 120, 44, 45, 38, 58, 77, 46, 15, 73, 107, 110, 51, 250, 92, 84, 41, 94, 76, 104, 364, 345, 239, 66, 242, 109, 89, 211, 142, 116, 312, 67, 184, 30, 31, 154, 388, 85, 130, 53, 254, 167, 43, 340, 35, 258, 199, 63, 235, 141, 227, 197, 113, 96, 36, 408, 241, 350, 858, 860, 638, 462, 595, 178, 86, 401, 140, 1600, 195, 139, 980, 210, 70, 390, 558, 179, 423, 60, 47, 375, 80, 1356, 192, 150, 206, 437, 395, 135, 912, 296, 29, 132, 122, 2380, 52, 240, 108, 111, 55, 263, 405, 218, 238, 145, 624, 175, 366, 796, 525, 136, 402, 133, 183, 119, 256, 406, 935, 213, 252, 98, 112, 131, 217, 229, 349, 299, 204, 502, 39, 65, 233, 365, 323, 360, 295, 78, 181, 103, 151, 42, 488, 102, 530, 279, 208, 54, 106, 1490, 845, 505, 88, 152, 264, 147, 320, 187, 148, 114, 128, 138, 126, 472, 137, 739, 282, 1118, 550, 542, 431, 79, 50, 1152, 115, 223, 370, 412, 19, 69, 166, 160, 324, 168, 680, 186, 34, 328, 91, 403]
# WARNING: Rare categories in column 'estrec' that occur less than 5.0% of the records: [2, 1, 8, 5, 11, 20, 3, 4, 10, 14, 13, 38, 9, 25, 44, 22, 36, 15, 19, 59, 34, 28, 51, 30, 57, 75, 45, 49, 81, 18, 6, 64, 41, 29, 42, 27, 77, 50, 139, 62, 67, 76, 12, 23, 16, 31, 40, 24, 33, 70, 107, 99, 174, 7, 124, 191, 26, 88, 61, 175, 120, 65, 80, 162, 134, 100, 83, 145, 68, 35, 94, 74, 93, 58, 87, 104, 235, 32, 52, 117, 533, 185, 60, 53, 17, 209, 109, 125, 105, 128, 159, 419, 212, 350, 232, 386, 92, 203, 223, 365, 135, 329, 119, 127, 137, 306, 413, 245, 234, 196, 334, 240, 1144, 21, 195, 348, 90, 522, 201, 270, 214, 394, 78, 153, 198, 103, 972, 131, 43, 1091, 325, 287, 284, 701, 253, 286, 606, 442, 129, 85, 317, 507, 312, 372, 569, 200, 222, 89, 378, 243, 271, 130, 71, 534, 144, 293, 225, 79, 604, 206, 95, 508, 158, 418, 138, 1060, 353, 98, 122, 328, 257, 294, 496, 628, 472, 121, 435, 151, 363, 187, 177, 792, 118, 299, 298, 338, 412, 544, 150, 189, 220, 339, 192, 73, 526, 37, 66, 753, 173, 263, 267, 898, 172, 46, 236, 477, 132, 91, 86, 48, 346, 101, 110, 749, 39, 152, 700, 300, 72, 273, 115, 307, 84]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 5
#       1 data_loader_kwargs = {
#       2     "time_to_event_column": "time",
#       3     "target_column": "cens",
#       4 }
# ----> 5 survival_synth_pipe.fit(df_train, data_loader_kwargs=data_loader_kwargs)
#
# Cell In[64], line 49, in SurvivalSynthPipe.fit(self, data_real, data_loader_kwargs)
#      45 # assign back to loader
#      46 loader.data = data_real
# ---> 49 self.generator.fit(loader)
#
# File ~/miniconda3/envs/crnsynth/lib/python3.9/site-packages/pydantic/decorator.py:40, in pydantic.decorator.validate_arguments.validate.wrapper_function()
#
# File ~/miniconda3/envs/crnsynth/lib/python3.9/site-packages/pydantic/decorator.py:134, in pydantic.decorator.ValidatedFunction.call()
#
# File ~/miniconda3/envs/crnsynth/lib/python3.9/site-packages/pydantic/decorator.py:206, in pydantic.decorator.ValidatedFunction.execute()
#
# File ~/miniconda3/envs/crnsynth/lib/python3.9/site-packages/synthcity/plugins/core/plugin.py:237, in Plugin.fit(self, X, *args, **kwargs)
#     230 self._schema = Schema(
#     231     data=X,
#     232     sampling_strategy=self.sampling_strategy,
#     233     random_state=self.random_state,
#     234 )
#     236 if X.is_tabular():
# --> 237     X, self._data_encoders = X.encode()
#     238     if self.compress_dataset:
#     239         X_hash = X.hash()
#
# File ~/miniconda3/envs/crnsynth/lib/python3.9/site-packages/synthcity/plugins/core/dataloader.py:244, in DataLoader.encode(self, encoders)
#     242             encoded[col] = encoder.transform(encoded[col]).values
#     243             encoders[col] = encoder
# --> 244 return self.from_info(encoded, self.info()), encoders
#
# File ~/miniconda3/envs/crnsynth/lib/python3.9/site-packages/synthcity/plugins/core/dataloader.py:647, in SurvivalAnalysisDataLoader.from_info(data, info)
#     644 if not isinstance(data, pd.DataFrame):
#     645     raise ValueError(f"Invalid data type {type(data)}")
# --> 647 return SurvivalAnalysisDataLoader(
#     648     data,
#     649     target_column=info["target_column"],
#     650     time_to_event_column=info["time_to_event_column"],
#     651     sensitive_features=info["sensitive_features"],
#     652     important_features=info["important_features"],
#     653     time_horizons=info["time_horizons"],
#     654     fairness_column=info["fairness_column"],
#     655 )
#
# File ~/miniconda3/envs/crnsynth/lib/python3.9/site-packages/pydantic/decorator.py:40, in pydantic.decorator.validate_arguments.validate.wrapper_function()
#
# File ~/miniconda3/envs/crnsynth/lib/python3.9/site-packages/pydantic/decorator.py:134, in pydantic.decorator.ValidatedFunction.call()
#
# File ~/miniconda3/envs/crnsynth/lib/python3.9/site-packages/pydantic/decorator.py:206, in pydantic.decorator.ValidatedFunction.execute()
#
# File ~/miniconda3/envs/crnsynth/lib/python3.9/site-packages/synthcity/plugins/core/dataloader.py:531, in SurvivalAnalysisDataLoader.__init__(self, data, time_to_event_column, target_column, time_horizons, sensitive_features, important_features, fairness_column, random_state, train_size, **kwargs)
#     529 row_diff = data.shape[0] - data_filtered.shape[0]
#     530 if row_diff > 0:
# --> 531     raise ValueError(
#     532         f"The time_to_event_column contains {row_diff} values less than or equal to zero. Please remove them."
#     533     )
#     535 if len(time_horizons) == 0:
#     536     time_horizons = np.linspace(T.min(), T.max(), num=5)[1:-1].tolist()
#
# ValueError: The time_to_event_column contains 109 values less than or equal to zero. Please remove them.

# %% [markdown]
# ## Generate
# Here we show how step by step how to generate synthetic data.

# %% [markdown]
# We define our synthesis pipeline, this will help us perform all the steps the right order. You can inherit common functionality across synthesis pipelines, while also adding your own data-specific methods to it.
#
# This ensures that you can benefit from a defined structure without needing to re-implement the generic elements, while still having the flexbility to customize it to your needs.

# %%
class AdultSynthPipe(BaseSynthPipe):
    def __init__(
        self,
        generator,
        data_name="adult",
        target_column="income",
        test_size=0.2,
        output_train_format=False,
        generalize=True,
        data_loader_name="generic",
        random_state=None,
        warn=True,
        verbose=2,
    ) -> None:
        super().__init__(
            generator=generator,
            data_name=data_name,
            target_column=target_column,
            test_size=test_size,
            output_train_format=output_train_format,
            generalize=generalize,
            data_loader_name=data_loader_name,
            random_state=random_state,
            warn=warn,
            verbose=verbose,
        )

    def process_data(self, data_real):
        # reduce columns
        columns_subset = [
            "age",
            "workclass",
            "education",
            "marital-status",
            "occupation",
            "relationship",
            "race",
            "sex",
            "hours-per-week",
            "native-country",
            "income",
        ]
        data_real = data_real[columns_subset]

        return super().process_data(data_real)

    def _generalize_data(self, data_real):
        data_real = data_real.bin_numeric_column(
            column_name="age", n_bins=5, col_min=17, col_max=90, strategy="quantile"
        ).bin_numeric_column(
            column_name="hours-per-week",
            n_bins=5,
            col_min=1,
            col_max=99,
            strategy="quantile",
        )
        return super()._generalize_data(data_real)

    def _reverse_generalization(self, data_synth):
        data_synth = data_synth.sample_from_binned_column(
            column_name="age",
            numeric_type="int",
            mean=38,
            std=13,
            random_state=self.random_state,
        ).sample_from_binned_column(
            column_name="hours-per-week",
            numeric_type="int",
            mean=40,
            std=10,
            random_state=self.random_state,
        )
        return super()._reverse_generalization(data_synth)


# choose generator
# generator = Plugins().get('privbayes-dk', epsilon=EPSILON)
generator = Plugins().get('marginal-dk', epsilon=EPSILON)

# initialize custom pipeline for dataset
synth_pipe = AdultSynthPipe(generator=generator)
# Out:
# [2024-01-11T09:51:45.590729+0100][2279][CRITICAL] module disabled: /Users/dknoors/miniconda3/envs/crnsynth/lib/python3.9/site-packages/synthcity/plugins/generic/plugin_goggle.py

# %% [markdown]
# Now we will prepare the data and split into training and testing. It's good to leave some holdout data that that can be used to compare the perfomance of models trained on real data and synthetic data.

# %%
# create copy to retain original data format
df = df_adult.copy()

# prepare data
df_train, df_test = synth_pipe.process_data(df)
df_train.head()
# Out:
#        age workclass     education      marital-status         occupation  \
# 29101   19         ?  Some-college       Never-married                  ?
# 10606   50   Private  Some-college  Married-civ-spouse  Machine-op-inspct
# 9414    62   Private  Some-college  Married-civ-spouse    Exec-managerial
# 1747    20   Private       HS-grad       Never-married       Adm-clerical
# 10677   25   Private     Bachelors       Never-married       Adm-clerical
#
#          relationship   race     sex  hours-per-week native-country income
# 29101  Other-relative  White  Female              30  United-States  <=50K
# 10606         Husband  White    Male              40  United-States  <=50K
# 9414          Husband  White    Male              40  United-States  <=50K
# 1747    Not-in-family  White  Female              40  United-States  <=50K
# 10677       Own-child  White  Female              40  United-States  <=50K

# %% [markdown]
# Train the generator on the processed training data. It might give some warning on categoreis that occur quite infrequently and might be a privacy risk to leave in your data. Decide how you would like to deal with them or proceed.

# %%
# train generator
synth_pipe.fit(df_train)
# Out:
# Bins whose width are too small (i.e., <= 1e-8). Consider decreasing the number of bins.
# WARNING: Rare categories in column 'workclass' that occur less than 5.0% of the records: ['State-gov', 'Self-emp-inc', 'Federal-gov', 'Without-pay', 'Never-worked']
# WARNING: Rare categories in column 'education' that occur less than 5.0% of the records: ['Assoc-voc', '11th', 'Assoc-acdm', '10th', '7th-8th', 'Prof-school', '9th', '12th', 'Doctorate', '5th-6th', '1st-4th', 'Preschool']
# WARNING: Rare categories in column 'marital-status' that occur less than 5.0% of the records: ['Separated', 'Widowed', 'Married-spouse-absent', 'Married-AF-spouse']
# WARNING: Rare categories in column 'occupation' that occur less than 5.0% of the records: ['Transport-moving', 'Handlers-cleaners', 'Farming-fishing', 'Tech-support', 'Protective-serv', 'Priv-house-serv', 'Armed-Forces']
# WARNING: Rare categories in column 'relationship' that occur less than 5.0% of the records: ['Wife', 'Other-relative']
# WARNING: Rare categories in column 'race' that occur less than 5.0% of the records: ['Asian-Pac-Islander', 'Amer-Indian-Eskimo', 'Other']
# WARNING: Rare categories in column 'native-country' that occur less than 5.0% of the records: ['Mexico', '?', 'Philippines', 'Germany', 'Puerto-Rico', 'El-Salvador', 'Canada', 'India', 'Cuba', 'England', 'South', 'Jamaica', 'China', 'Dominican-Republic', 'Italy', 'Vietnam', 'Poland', 'Japan', 'Guatemala', 'Columbia', 'Taiwan', 'Iran', 'Haiti', 'Portugal', 'Peru', 'Nicaragua', 'France', 'Greece', 'Ecuador', 'Hong', 'Cambodia', 'Ireland', 'Thailand', 'Trinadad&Tobago', 'Yugoslavia', 'Honduras', 'Laos', 'Scotland', 'Hungary', 'Outlying-US(Guam-USVI-etc)', 'Holand-Netherlands']
# Using data loader for generic
# Marginal fitted: age
# Marginal fitted: workclass
# Marginal fitted: education
# Marginal fitted: marital-status
# Marginal fitted: occupation
# Marginal fitted: relationship
# Marginal fitted: race
# Marginal fitted: sex
# Marginal fitted: hours-per-week
# Marginal fitted: native-country
# Marginal fitted: income

# %% [markdown]
# After training the synthesizer, we can now sample records from it to generate a synthetic dataset.

# %%
# generate synthetic data
df_synth = synth_pipe.generate(n_records=None)
df_synth.head()
# Out:
# Column sampled: age
# Column sampled: workclass
# Column sampled: education
# Column sampled: marital-status
# Column sampled: occupation
# Column sampled: relationship
# Column sampled: race
# Column sampled: sex
# Column sampled: hours-per-week
# Column sampled: native-country
# Column sampled: income
# Column sampled: age
# Column sampled: workclass
# Column sampled: education
# Column sampled: marital-status
# Column sampled: occupation
# Column sampled: relationship
# Column sampled: race
# Column sampled: sex
# Column sampled: hours-per-week
# Column sampled: native-country
# Column sampled: income
#    age workclass education      marital-status        occupation relationship  \
# 0   21   Private   HS-grad  Married-civ-spouse      Adm-clerical    Own-child
# 1   47   Private      11th  Married-civ-spouse      Craft-repair    Own-child
# 2   23   Private   HS-grad       Never-married  Transport-moving    Own-child
# 3   24   Private      11th            Divorced      Craft-repair         Wife
# 4   35   Private   HS-grad       Never-married      Armed-Forces      Husband
#
#     race     sex  hours-per-week native-country income
# 0  White    Male              54  United-States   >50K
# 1  White    Male              43  United-States  <=50K
# 2  White    Male              49  United-States  <=50K
# 3  White    Male              45  United-States  <=50K
# 4  White  Female              26  United-States  <=50K

# %% [markdown]
# We still might have to do some post-processing to fix inconsistencies, reorder columns or add columns.

# %%
# post-process data
df_synth = synth_pipe.postprocess_synthetic_data(df_synth)

df_synth.head()
# Out:
#    age workclass education      marital-status        occupation relationship  \
# 0   21   Private   HS-grad  Married-civ-spouse      Adm-clerical    Own-child
# 1   47   Private      11th  Married-civ-spouse      Craft-repair    Own-child
# 2   23   Private   HS-grad       Never-married  Transport-moving    Own-child
# 3   24   Private      11th            Divorced      Craft-repair         Wife
# 4   35   Private   HS-grad       Never-married      Armed-Forces      Husband
#
#     race     sex  hours-per-week native-country income
# 0  White    Male              54  United-States   >50K
# 1  White    Male              43  United-States  <=50K
# 2  White    Male              49  United-States  <=50K
# 3  White    Male              45  United-States  <=50K
# 4  White  Female              26  United-States  <=50K

# %% [markdown]
# SynthPipe allows you to perform a full synthesis pipeline step by step and allow you to inspect what happens. However, you can also use run() to perform all steps in order at once.

# %%
# choose generator
generator = Plugins().get('privbayes-dk', epsilon=EPSILON)

# initialize custom pipeline for dataset
synth_pipe = AdultSynthPipe(generator=generator, output_train_format=True)

synth_pipe.run(df_adult)
# Out:
# [2024-01-08T20:48:47.710845+0100][16982][CRITICAL] module disabled: /Users/dknoors/miniconda3/envs/crnsynth/lib/python3.9/site-packages/synthcity/plugins/generic/plugin_goggle.py
# Bins whose width are too small (i.e., <= 1e-8). Consider decreasing the number of bins.
# WARNING: Rare categories in column 'workclass' that occur less than 5.0% of the records: ['State-gov', 'Self-emp-inc', 'Federal-gov', 'Without-pay', 'Never-worked']
# WARNING: Rare categories in column 'education' that occur less than 5.0% of the records: ['Assoc-voc', '11th', 'Assoc-acdm', '10th', '7th-8th', 'Prof-school', '9th', '12th', 'Doctorate', '5th-6th', '1st-4th', 'Preschool']
# WARNING: Rare categories in column 'marital-status' that occur less than 5.0% of the records: ['Separated', 'Widowed', 'Married-spouse-absent', 'Married-AF-spouse']
# WARNING: Rare categories in column 'occupation' that occur less than 5.0% of the records: ['Transport-moving', 'Handlers-cleaners', 'Farming-fishing', 'Tech-support', 'Protective-serv', 'Priv-house-serv', 'Armed-Forces']
# WARNING: Rare categories in column 'relationship' that occur less than 5.0% of the records: ['Wife', 'Other-relative']
# WARNING: Rare categories in column 'race' that occur less than 5.0% of the records: ['Asian-Pac-Islander', 'Amer-Indian-Eskimo', 'Other']
# WARNING: Rare categories in column 'native-country' that occur less than 5.0% of the records: ['Mexico', '?', 'Philippines', 'Germany', 'Puerto-Rico', 'El-Salvador', 'Canada', 'India', 'Cuba', 'England', 'South', 'Jamaica', 'China', 'Dominican-Republic', 'Italy', 'Vietnam', 'Poland', 'Japan', 'Guatemala', 'Columbia', 'Taiwan', 'Iran', 'Haiti', 'Portugal', 'Peru', 'Nicaragua', 'France', 'Greece', 'Ecuador', 'Hong', 'Cambodia', 'Ireland', 'Thailand', 'Trinadad&Tobago', 'Yugoslavia', 'Honduras', 'Laos', 'Scotland', 'Hungary', 'Outlying-US(Guam-USVI-etc)', 'Holand-Netherlands']
# Using data loader for generic
# 1/11 - Root of network: relationship
#
# 2/11 - Evaluating next attribute to add to network
# Number of AttributeParentPair candidates: 10
# Selected attribute: 'marital-status' - with parents: ('relationship',)
#
# 3/11 - Evaluating next attribute to add to network
# Number of AttributeParentPair candidates: 14
# Selected attribute: 'age' - with parents: ('marital-status',)
#
# 4/11 - Evaluating next attribute to add to network
# Number of AttributeParentPair candidates: 21
# Selected attribute: 'sex' - with parents: ('relationship', 'marital-status')
#
# 5/11 - Evaluating next attribute to add to network
# Number of AttributeParentPair candidates: 24
# Selected attribute: 'income' - with parents: ('sex', 'relationship', 'age')
#
# 6/11 - Evaluating next attribute to add to network
# Number of AttributeParentPair candidates: 29
# Selected attribute: 'occupation' - with parents: ('sex', 'income')
#
# 7/11 - Evaluating next attribute to add to network
# Number of AttributeParentPair candidates: 28
# Selected attribute: 'workclass' - with parents: ('occupation',)
#
# 8/11 - Evaluating next attribute to add to network
# Number of AttributeParentPair candidates: 26
# Selected attribute: 'education' - with parents: ('income', 'age')
#
# 9/11 - Evaluating next attribute to add to network
# Number of AttributeParentPair candidates: 23
# Selected attribute: 'hours-per-week' - with parents: ('occupation', 'income')
#
# 10/11 - Evaluating next attribute to add to network
# Number of AttributeParentPair candidates: 18
# Selected attribute: 'race' - with parents: ('sex', 'workclass', 'income')
#
# 11/11 - Evaluating next attribute to add to network
# Number of AttributeParentPair candidates: 2
# Selected attribute: 'native-country' - with parents: ('hours-per-week',)
#
# Learned Network Structure
#
# Learning conditional probabilities: relationship - with parents None ~ estimated size: 6
# Learning conditional probabilities: marital-status - with parents ('relationship',) ~ estimated size: 42
# Learning conditional probabilities: age - with parents ('marital-status',) ~ estimated size: 35
# Learning conditional probabilities: sex - with parents ('relationship', 'marital-status') ~ estimated size: 84
# Learning conditional probabilities: income - with parents ('sex', 'relationship', 'age') ~ estimated size: 120
# Learning conditional probabilities: occupation - with parents ('sex', 'income') ~ estimated size: 60
# Learning conditional probabilities: workclass - with parents ('occupation',) ~ estimated size: 135
# Learning conditional probabilities: education - with parents ('income', 'age') ~ estimated size: 160
# Learning conditional probabilities: hours-per-week - with parents ('occupation', 'income') ~ estimated size: 120
# Learning conditional probabilities: race - with parents ('sex', 'workclass', 'income') ~ estimated size: 180
# Learning conditional probabilities: native-country - with parents ('hours-per-week',) ~ estimated size: 168
# Number of records generated: 589 / 26048
# invalid value encountered in divide
# invalid value encountered in divide
# Number of records generated: 26048 / 26048
# Synthetic Data Generated
#
# Number of records generated: 26048 / 26048
# Synthetic Data Generated
#        age     workclass     education      marital-status         occupation  \
# 0       39  Self-emp-inc     Bachelors           Separated    Exec-managerial
# 1       60   Without-pay       Masters            Divorced       Tech-support
# 2       23       Private  Some-college       Never-married      Other-service
# 3       20       Private          10th       Never-married              Sales
# 4       31       Private       HS-grad  Married-civ-spouse   Transport-moving
# ...    ...           ...           ...                 ...                ...
# 26043   70       Private    Assoc-acdm            Divorced      Other-service
# 26044   33       Private       HS-grad  Married-civ-spouse  Handlers-cleaners
# 26045   34       Private       HS-grad            Divorced      Other-service
# 26046   43       Private       Masters            Divorced     Prof-specialty
# 26047   62       Private       Masters            Divorced      Other-service
#
#          relationship                race     sex  hours-per-week  \
# 0           Unmarried               White  Female              43
# 1       Not-in-family  Asian-Pac-Islander    Male              48
# 2           Unmarried               White  Female              38
# 3           Own-child               White    Male              46
# 4             Husband               White    Male              24
# ...               ...                 ...     ...             ...
# 26043   Not-in-family               White  Female              34
# 26044         Husband               White    Male              49
# 26045   Not-in-family               White  Female              33
# 26046  Other-relative               White    Male              60
# 26047   Not-in-family               White    Male              40
#
#       native-country income
# 0      United-States  <=50K
# 1      United-States  <=50K
# 2             Mexico  <=50K
# 3      United-States  <=50K
# 4      United-States  <=50K
# ...              ...    ...
# 26043       Portugal  <=50K
# 26044  United-States  <=50K
# 26045  United-States  <=50K
# 26046  United-States   >50K
# 26047    Puerto-Rico  <=50K
#
# [26048 rows x 11 columns]

# %% [markdown]
# Note: PrivBayes implementation of synthetic-data-generation library (DK) is added to plugins. This version of privbayes differs with the one included synthcity:
# - R score function instead of Mutual Information - which has a lower sensitivity and thus requires less noise to compute.
# - Candidate attribute-parent pairs (AP-pairs) are determined based on the theta-usefulness criterion instead of setting a fixed max degree K.

# %% [markdown]
# ## Metrics
# Below an example on how to compute a privacy metric. Note the synthetic score (DCR and NNDR) > test score to minimize privacy leakage.

# %%
from crnsynth.evaluation.custom_privacy_metrics.dcr import DistanceClosestRecord
from crnsynth.evaluation.custom_privacy_metrics.nndr import NearestNeighborDistanceRatio

# convert to dataloaders
loader_train = GenericDataLoader(df_train)
loader_test = GenericDataLoader(df_test)
loader_synth = GenericDataLoader(df_synth)

# calculate metrics
# specify percentile for DCR, default is 5 (5th percentile) as we are most interested in distance of the closest records.
# set to 50 for median
percentile = 5
dcr = DistanceClosestRecord(percentile=percentile).evaluate(X_gt=loader_train, X_syn=loader_synth, X_test=loader_test)

print(f"DCR synthetic: {dcr['dcr_synth']:.3f}")
print(f"DCR test: {dcr['dcr_gt']:.3f}")

nndr = NearestNeighborDistanceRatio(percentile=percentile).evaluate(X_gt=loader_train, X_syn=loader_synth, X_test=loader_test)
print(f"NNDR synthetic: {nndr['nndr_synth']:.3f}")
print(f"NNDR test: {nndr['nndr_gt']:.3f}")
# Out:
# DCR synthetic: 0.375
# DCR test: 0.000
# NNDR synthetic: 0.667
# NNDR test: 0.000

# %%
from crnsynth.evaluation.custom_privacy_metrics.utils import compute_distance_nn
import matplotlib.pyplot as plt
import seaborn as sns

distances_test, distances_synth = compute_distance_nn(
    df_train=df_train,
    df_test=df_test,
    df_synth=df_synth,
    categorical_cols=None,
)

# print distances test and synthetic with counts
dt, ct  = np.unique(distances_test[:, 0], return_counts=True)
dt, ct = np.unique(distances_synth[:, 0], return_counts=True)


print(f'Test distances {dt} with counts {ct}')
print(f'Synthetic distances: {dt} with counts {ct}')

# plot distances as distribution in same figure
fig, ax = plt.subplots(figsize=(10, 5))
sns.distplot(distances_test[:, 0], ax=ax, label='test')

# plot 5th percentile  and median test
percentile_test = np.percentile(distances_test[:, 0], percentile)
median_test = np.median(distances_test[:, 0])
ax.axvline(percentile_test, color='red', label=f'{percentile}th percentile')
ax.axvline(median_test, color='green', label='median')

sns.distplot(distances_synth[:, 0], ax=ax, label='synthetic')
# plot median synthetic
median_synth = np.median(distances_synth[:, 0])

ax.legend()
ax.set_title(f'Distribution of distances to nearest neighbor')
# Out:
# Test distances [0.    0.125 0.25  0.375 0.5   0.625 0.75  0.875 1.   ] with counts [  58  155  851 1968 3623 5697 5642 5683 8884]
# Synthetic distances: [0.    0.125 0.25  0.375 0.5   0.625 0.75  0.875 1.   ] with counts [  58  155  851 1968 3623 5697 5642 5683 8884]
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Text(0.5, 1.0, 'Distribution of distances to nearest neighbor')

# %%
distances_synth
# Out:
# array([[0.875, 1.   ],
#        [0.625, 0.75 ],
#        [0.375, 0.375],
#        ...,
#        [0.75 , 0.875],
#        [0.5  , 0.625],
#        [0.375, 0.375]])

# %%
distances_test
# Out:
# array([[0.   , 0.125],
#        [1.   , 1.   ],
#        [0.375, 0.625],
#        ...,
#        [0.875, 0.875],
#        [0.5  , 0.5  ],
#        [0.5  , 0.5  ]])

# %%
np.percentile(distances_test[:, 0], 50)
# Out:
# 0.25

# %%
np.percentile(distances_synth[:, 0], 50)
# Out:
# 0.7499999999999998

# %%
np.unique(distances_test[:, 0], return_counts=True)
# Out:
# (array([0.   , 0.125, 0.25 , 0.375, 0.5  , 0.625, 0.75 , 0.875, 1.   ]),
#  array([1240,  766, 1576,  788,  836,  441,  372,  207,  287]))

# %%
df_concat_unique = pd.concat([df_train.drop_duplicates(keep=False), df_test])
df_dup = df_concat_unique[df_concat_unique.duplicated(keep='first')]

# %%
df_dup
# Out:
#        age workclass     education      marital-status         occupation  \
# 13077   57   Private       HS-grad  Married-civ-spouse              Sales
# 21997   34   Private       HS-grad            Divorced  Machine-op-inspct
# 22684   54   Private       Masters  Married-civ-spouse     Prof-specialty
# 8964    22   Private     Bachelors       Never-married    Exec-managerial
# 8215    22   Private       HS-grad       Never-married      Other-service
# ...    ...       ...           ...                 ...                ...
# 24643   53   Private       HS-grad  Married-civ-spouse       Craft-repair
# 7672    33   Private       HS-grad  Married-civ-spouse    Exec-managerial
# 14344   19         ?  Some-college       Never-married                  ?
# 8270    43   Private     Bachelors  Married-civ-spouse     Prof-specialty
# 1920    32   Private       HS-grad           Separated       Adm-clerical
#
#         relationship   race     sex  hours-per-week native-country income
# 13077        Husband  White    Male              40  United-States  <=50K
# 21997      Unmarried  White  Female              40  United-States  <=50K
# 22684        Husband  White    Male              40  United-States   >50K
# 8964   Not-in-family  White  Female              30  United-States  <=50K
# 8215       Own-child  White  Female              35  United-States  <=50K
# ...              ...    ...     ...             ...            ...    ...
# 24643        Husband  White    Male              46  United-States   >50K
# 7672         Husband  White    Male              50  United-States  <=50K
# 14344      Own-child  White  Female              40  United-States  <=50K
# 8270         Husband  White    Male              50  United-States   >50K
# 1920       Unmarried  White  Female              40  United-States  <=50K
#
# [874 rows x 11 columns]
